# %%
import os
import json
import glob

# === Set output path for your .jsonl dataset description ===
# output_jsonl_path = "/data/usr/yb107/colon_data/colon_dataset.jsonl"
output_jsonl_path = "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset.jsonl"

# === Fixed base paths ===
# image_dir = "/data/usr/yb107/c_grade_colons/images"
# mask_root = "/data/usr/yb107/c_grade_colons/3d_vlsm_label_masks"

mask_roots = [
    "/data/usr/yb107/colon_data/refined_by_mobina/a_grade_colons_not_in_refined_by_md/masks/",
    "/data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/",
    "/data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/",
    "/data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/",
]
entries = []

# === Go through each image ===
# image_files = sorted(glob.glob(os.path.join(image_dir, "*.nii.gz")))

# Go through each .nii.gz file in labels directory
# files = glob.glob(f"{mask_root}/*.nii.gz")
files = []
files.extend(glob.glob(os.path.join(mask_roots[0], "*.nii.gz")))
files.extend(glob.glob(os.path.join(mask_roots[1], "*.nii.gz")))
files.extend(glob.glob(os.path.join(mask_roots[2], "*.nii.gz")))
files.extend(glob.glob(os.path.join(mask_roots[3], "*.nii.gz")))

print(f"Found {len(files)} files in total across all mask roots.")
print(f"Files: {files[0]}")

for mask_path in files:
    # patient_name = os.path.basename(image_path).replace(".nii.gz", "")
    # mask_path = os.path.join(mask_root, patient_name, "colon.nii.gz")
    # image_path = mask_path.replace("3d_vlsm_label_masks", "images")

    # # === Check if mask exists, raise error if not ===
    if not os.path.exists(mask_path):
        raise FileNotFoundError(f"Missing mask for: {mask_path}")

    # entries.append({"image": image_path, "mask": mask_path})
    entries.append({"mask": mask_path})

# === Write to .jsonl ===
with open(output_jsonl_path, "w") as f:
    for entry in entries:
        f.write(json.dumps(entry) + "\n")

print(f"[✓] Wrote {len(entries)} valid entries to {output_jsonl_path}")
# Out:
# Found 419 files in total across all mask roots.
# Files: /data/usr/yb107/colon_data/refined_by_mobina/a_grade_colons_not_in_refined_by_md/masks/Patient_00101_Study_73554_Series_04.nii.gz
# [✓] Wrote 419 valid entries to /home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset.jsonl

# %%
import json
import random

output_jsonl_path = "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset.jsonl"


def divide_jsonl_train_val_test(
    jsonl_file, train_file, val_file, test_file, train_ratio=0.85, val_ratio=0.10
):
    """Divide the JSONL dataset into train, validation, and test sets."""
    with open(jsonl_file, "r") as f:
        entries = [json.loads(line) for line in f]

    # shuffle the entries
    random.shuffle(entries)

    total_entries = len(entries)
    train_end = int(total_entries * train_ratio)
    val_end = int(total_entries * (train_ratio + val_ratio))

    with open(train_file, "w") as f:
        for entry in entries[:train_end]:
            f.write(json.dumps(entry) + "\n")

    with open(val_file, "w") as f:
        for entry in entries[train_end:val_end]:
            f.write(json.dumps(entry) + "\n")

    with open(test_file, "w") as f:
        for entry in entries[val_end:]:
            f.write(json.dumps(entry) + "\n")


divide_jsonl_train_val_test(
    "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset_with_body_filled.jsonl",
    "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset_with_body_filled.jsonl_train.jsonl",
    "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset_with_body_filled.jsonl_val.jsonl",
    "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset_with_body_filled.jsonl_test.jsonl",
    train_ratio=0.85,
    val_ratio=0.10,
)

# %% [markdown]
# # Copy Data from Drcc to Capri

# %%
import os
import subprocess

# === Set these ===
base_image_dir = "/scratch/railabs/ld258/projects/3d_vlsm/data/images/"
remote_user = "yb107"
remote_host = "plp-capri"
remote_target_dir = "/data/usr/yb107/colon_data/3d_vlsm/"

case_names = sorted(common_all)

print(f"Total cases to copy: {len(case_names)}")
# # === Loop and copy ===
# for case in case_names:
#     # Find matching files in base_image_dir
#     matching_files = [f for f in os.listdir(base_image_dir) if f.startswith(case)]

#     for file in matching_files:
#         local_path = os.path.join(base_image_dir, file)

#         # Check if file exists
#         if not os.path.isfile(local_path):
#             print(f"[!] File not found: {local_path}")
#             continue

#         remote_path = f"{remote_user}@{remote_host}:{remote_target_dir}"

#         print(f"Copying {file} → {remote_path}")

#         # Run scp (will ask for password unless SSH keys are set up)
#         subprocess.run(["scp", local_path, remote_path])

# %%
nrrd_base_paths = [
    "/data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/",
    "/data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/",
    "/data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/",
]

import SimpleITK as sitk
from multiprocessing import Pool
import os


def process_nrrd_file(nrrd_path):
    """Convert NRRD file to NIfTI and save it in the same directory."""
    try:
        image = sitk.ReadImage(nrrd_path)
        # nifti_path = nrrd_path.replace(".nrrd", ".nii.gz")
        basename = os.path.basename(nrrd_path)
        filename = basename.split(".nii.gz")[0]
        os.makedirs(os.path.join(os.path.dirname(nrrd_path), "masks"), exist_ok=True)
        nifti_path = os.path.join(
            os.path.dirname(nrrd_path), "masks", f"{filename}.nii.gz"
        )
        sitk.WriteImage(image, nifti_path)
        print(f"Converted {nrrd_path} to {nifti_path}")
    except Exception as e:
        print(f"Error processing {nrrd_path}: {e}")


def convert_nrrd_to_nifti(nrrd_base_paths):
    """Convert all NRRD files in the given base paths to NIfTI format."""
    nrrd_files = []
    for base_path in nrrd_base_paths:
        nrrd_files.extend(glob.glob(os.path.join(base_path, "*.nrrd")))

    print(f"Found {len(nrrd_files)} NRRD files to convert.")

    with Pool(processes=os.cpu_count()) as pool:
        pool.map(process_nrrd_file, nrrd_files)


convert_nrrd_to_nifti(nrrd_base_paths)
# Out:
# Found 245 NRRD files to convert.
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00927_Study_17475_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00927_Study_17475_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00351_Study_77248_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00351_Study_77248_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00895_Study_77626_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00895_Study_77626_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00138_Study_73227_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00138_Study_73227_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00006_Study_16077_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00006_Study_16077_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00935_Study_16342_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00935_Study_16342_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00726_Study_74672_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00726_Study_74672_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00520_Study_55181_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00520_Study_55181_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00926_Study_58517_Series_03_0.8.5.2.3.7.35831.2.1.1.38176501742001782288244230700000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00926_Study_58517_Series_03_0.8.5.2.3.7.35831.2.1.1.38176501742001782288244230700000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00036_Study_46184_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00036_Study_46184_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00534_Study_65512_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00534_Study_65512_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00890_Study_37121_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00890_Study_37121_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00579_Study_04851_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00579_Study_04851_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00902_Study_67733_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00902_Study_67733_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00078_Study_22170_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00078_Study_22170_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00357_Study_27466_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00357_Study_27466_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00738_Study_45634_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00738_Study_45634_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00009_Study_74723_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00009_Study_74723_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02045_Study_85107_Series_04_3.0.7.0.7.5.75320.2.1.1.57524314723722085646775862680000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02045_Study_85107_Series_04_3.0.7.0.7.5.75320.2.1.1.57524314723722085646775862680000.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00133_Study_47067_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00133_Study_47067_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00372_Study_40031_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00372_Study_40031_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00730_Study_86586_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00730_Study_86586_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00294_Study_27816_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00294_Study_27816_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00908_Study_35142_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00908_Study_35142_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00926_Study_52882_Series_03_1.6.0.3.0.2.41255.2.1.1.81612735614822631482310464450000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00926_Study_52882_Series_03_1.6.0.3.0.2.41255.2.1.1.81612735614822631482310464450000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00807_Study_52682_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00807_Study_52682_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00026_Study_03634_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00026_Study_03634_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00627_Study_13148_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00627_Study_13148_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00335_Study_84030_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00335_Study_84030_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02106_Study_14020_Series_03_0.2.2.2.6.7.11077.2.1.1.46705580234376121212716423850000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02106_Study_14020_Series_03_0.2.2.2.6.7.11077.2.1.1.46705580234376121212716423850000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00219_Study_82141_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00219_Study_82141_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00821_Study_52186_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00821_Study_52186_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00793_Study_82772_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00793_Study_82772_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00108_Study_05142_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00108_Study_05142_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00157_Study_52443_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00157_Study_52443_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00809_Study_81605_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00809_Study_81605_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00917_Study_03813_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00917_Study_03813_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00213_Study_18742_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00213_Study_18742_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02193_Study_72321_Series_04_4.1.1.2.3.3.04202.2.1.1.00603517113037506772552007610000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02193_Study_72321_Series_04_4.1.1.2.3.3.04202.2.1.1.00603517113037506772552007610000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00069_Study_04650_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00069_Study_04650_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01588_Study_22805_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01588_Study_22805_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00450_Study_62804_Series_03_4.5.7.4.4.1.17756.2.1.1.81258068640876161125345107830000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00450_Study_62804_Series_03_4.5.7.4.4.1.17756.2.1.1.81258068640876161125345107830000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00077_Study_23652_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00077_Study_23652_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00697_Study_75768_Series_05_1.4.1.0.0.0.36622.2.1.1.18186014715538445151753515320000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00697_Study_75768_Series_05_1.4.1.0.0.0.36622.2.1.1.18186014715538445151753515320000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00056_Study_87522_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00056_Study_87522_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02625_Study_37287_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02625_Study_37287_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00662_Study_14676_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00662_Study_14676_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00301_Study_51108_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00301_Study_51108_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01800_Study_34433_Series_03.nii.gz.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01800_Study_34433_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00835_Study_27722_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00835_Study_27722_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00544_Study_22135_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00544_Study_22135_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01644_Study_73432_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01644_Study_73432_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02585_Study_73021_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02585_Study_73021_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_00431_Study_01401_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_00431_Study_01401_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_00576_Study_08147_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_00576_Study_08147_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02335_Study_36425_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02335_Study_36425_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00562_Study_22840_Series_03_5.7.6.4.5.7.10067.2.1.1.27633252273240838324266124880000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00562_Study_22840_Series_03_5.7.6.4.5.7.10067.2.1.1.27633252273240838324266124880000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01540_Study_45684_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01540_Study_45684_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00722_Study_24245_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00722_Study_24245_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01310_Study_00173_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01310_Study_00173_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01931_Study_00685_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01931_Study_00685_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02348_Study_77523_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02348_Study_77523_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02394_Study_68843_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02394_Study_68843_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00489_Study_60853_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00489_Study_60853_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01398_Study_43566_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01398_Study_43566_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02468_Study_84568_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02468_Study_84568_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02417_Study_15335_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02417_Study_15335_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00080_Study_47686_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00080_Study_47686_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00786_Study_78228_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00786_Study_78228_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00230_Study_65327_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00230_Study_65327_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_00038_Study_58218_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_00038_Study_58218_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01854_Study_61406_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01854_Study_61406_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00803_Study_23641_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00803_Study_23641_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00595_Study_07564_Series_03_5.8.0.6.0.2.01624.2.1.1.26181605372805027880358577750000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00595_Study_07564_Series_03_5.8.0.6.0.2.01624.2.1.1.26181605372805027880358577750000.nii.gz
#
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00345_Study_85465_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00345_Study_85465_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00551_Study_38702_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00551_Study_38702_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01491_Study_04750_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01491_Study_04750_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_01113_Study_10102_Series_03_6.0.3.7.6.1.42043.2.1.1.38672657077380573842427077000000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_01113_Study_10102_Series_03_6.0.3.7.6.1.42043.2.1.1.38672657077380573842427077000000.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00290_Study_60156_Series_03.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00290_Study_60156_Series_03.nii.seg.nrrd.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01653_Study_74630_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01653_Study_74630_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02033_Study_71035_Series_03_8.8.6.2.5.6.12524.2.1.1.73712056600281174072122075070000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02033_Study_71035_Series_03_8.8.6.2.5.6.12524.2.1.1.73712056600281174072122075070000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01800_Study_34433_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01800_Study_34433_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02225_Study_60027_Series_03_2.8.4.5.2.8.24801.2.1.1.42604733221472242630027228570000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02225_Study_60027_Series_03_2.8.4.5.2.8.24801.2.1.1.42604733221472242630027228570000.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02204_Study_16731_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02204_Study_16731_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00893_Study_55886_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00893_Study_55886_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_00657_Study_50813_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_00657_Study_50813_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00110_Study_81621_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00110_Study_81621_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00797_Study_58743_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00797_Study_58743_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00713_Study_62082_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00713_Study_62082_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00257_Study_80566_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00257_Study_80566_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00430_Study_63011_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00430_Study_63011_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00591_Study_14067_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00591_Study_14067_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_02155_Study_45071_Series_06.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_02155_Study_45071_Series_06.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02117_Study_58631_Series_05_1.2.4.8.8.4.88327.2.1.1.47466076628307352024885355120000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02117_Study_58631_Series_05_1.2.4.8.8.4.88327.2.1.1.47466076628307352024885355120000.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00772_Study_41725_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00772_Study_41725_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00083_Study_38861_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00083_Study_38861_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00200_Study_05460_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00200_Study_05460_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00425_Study_81020_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00425_Study_81020_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00549_Study_42282_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00549_Study_42282_Series_04.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00834_Study_73065_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00834_Study_73065_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02285_Study_01053_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02285_Study_01053_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00861_Study_84406_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00861_Study_84406_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_01836_Study_83806_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_01836_Study_83806_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00019_Study_42648_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00019_Study_42648_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00017_Study_03180_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00017_Study_03180_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/Patient_02225_Study_60027_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/female_cases_refined_by_md/masks/Patient_02225_Study_60027_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00675_Study_71136_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00675_Study_71136_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_01018_Study_23335_Series_05_2.0.5.0.3.1.40816.2.1.1.47082425387167780565033284510000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_01018_Study_23335_Series_05_2.0.5.0.3.1.40816.2.1.1.47082425387167780565033284510000.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00626_Study_66424_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00626_Study_66424_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00768_Study_28780_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00768_Study_28780_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00378_Study_82323_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00378_Study_82323_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00784_Study_75567_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00784_Study_75567_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02260_Study_20246_Series_03_2.4.3.2.1.1.70654.2.1.1.47142325008758377340455103080000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02260_Study_20246_Series_03_2.4.3.2.1.1.70654.2.1.1.47142325008758377340455103080000.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00114_Study_64230_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00114_Study_64230_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00884_Study_17144_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00884_Study_17144_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00585_Study_88367_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00585_Study_88367_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00320_Study_15315_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00320_Study_15315_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_01094_Study_86681_Series_03_7.3.1.7.5.2.34268.2.1.1.38737707087204676212078174020000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_01094_Study_86681_Series_03_7.3.1.7.5.2.34268.2.1.1.38737707087204676212078174020000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01758_Study_11378_Series_05.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01758_Study_11378_Series_05.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00717_Study_52055_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00717_Study_52055_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00563_Study_35120_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00563_Study_35120_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00775_Study_00572_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00775_Study_00572_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01078_Study_10301_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01078_Study_10301_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00051_Study_56111_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00051_Study_56111_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00688_Study_26121_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00688_Study_26121_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00116_Study_08028_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00116_Study_08028_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00541_Study_12457_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00541_Study_12457_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00473_Study_88005_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00473_Study_88005_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00084_Study_20201_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00084_Study_20201_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00723_Study_70448_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00723_Study_70448_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00441_Study_34130_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00441_Study_34130_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00903_Study_73352_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00903_Study_73352_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00191_Study_76413_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00191_Study_76413_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00385_Study_36832_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00385_Study_36832_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00321_Study_52168_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00321_Study_52168_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00647_Study_51380_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00647_Study_51380_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00094_Study_82014_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00094_Study_82014_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00879_Study_12880_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00879_Study_12880_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00663_Study_75657_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00663_Study_75657_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00704_Study_72714_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00704_Study_72714_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00858_Study_41582_Series_03.nii.gz.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00858_Study_41582_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00739_Study_14200_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00739_Study_14200_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00094_Study_82014_Series_03.nii.gz.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00094_Study_82014_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00878_Study_04755_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00878_Study_04755_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00721_Study_33076_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00721_Study_33076_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00645_Study_71107_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00645_Study_71107_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00858_Study_41582_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00858_Study_41582_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00058_Study_76664_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00058_Study_76664_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00269_Study_27735_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00269_Study_27735_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00519_Study_63215_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00519_Study_63215_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00569_Study_57045_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00569_Study_57045_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01925_Study_40726_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01925_Study_40726_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00012_Study_23776_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00012_Study_23776_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00798_Study_48421_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00798_Study_48421_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01319_Study_27252_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01319_Study_27252_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_02155_Study_45071_Series_06.nii.gz.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_02155_Study_45071_Series_06.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00524_Study_87078_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00524_Study_87078_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00630_Study_61250_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00630_Study_61250_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00584_Study_15672_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00584_Study_15672_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00205_Study_57330_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00205_Study_57330_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00619_Study_40830_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00619_Study_40830_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00733_Study_40585_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00733_Study_40585_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00488_Study_03304_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00488_Study_03304_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00364_Study_50122_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00364_Study_50122_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00032_Study_47243_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00032_Study_47243_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01799_Study_07874_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01799_Study_07874_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00658_Study_07752_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00658_Study_07752_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00791_Study_55656_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00791_Study_55656_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00327_Study_16848_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00327_Study_16848_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00528_Study_75524_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00528_Study_75524_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00877_Study_38647_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00877_Study_38647_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00322_Study_33734_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00322_Study_33734_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00130_Study_77352_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00130_Study_77352_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00108_Study_05142_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00108_Study_05142_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02401_Study_60430_Series_03_4.4.3.2.8.7.63100.2.1.1.51236481556354213001465778750000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02401_Study_60430_Series_03_4.4.3.2.8.7.63100.2.1.1.51236481556354213001465778750000.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01669_Study_02661_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01669_Study_02661_Series_03.nii.gz
# ...
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00398_Study_85328_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00398_Study_85328_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_02162_Study_38835_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_02162_Study_38835_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00802_Study_46218_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00802_Study_46218_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00068_Study_57728_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00068_Study_57728_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01769_Study_00612_Series_05.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01769_Study_00612_Series_05.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00016_Study_22564_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00016_Study_22564_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00503_Study_36467_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00503_Study_36467_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00875_Study_85738_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00875_Study_85738_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00659_Study_53805_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00659_Study_53805_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00771_Study_56443_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00771_Study_56443_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00395_Study_45806_Series_03_5.2.3.6.2.2.76325.2.1.1.14026511432374562770876581880000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00395_Study_45806_Series_03_5.2.3.6.2.2.76325.2.1.1.14026511432374562770876581880000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00492_Study_66113_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00492_Study_66113_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00512_Study_66514_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00512_Study_66514_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_01694_Study_12428_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_01694_Study_12428_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00750_Study_32367_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00750_Study_32367_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00545_Study_46356_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00545_Study_46356_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00112_Study_25474_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00112_Study_25474_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00718_Study_33104_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00718_Study_33104_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00801_Study_32730_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00801_Study_32730_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00271_Study_33786_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00271_Study_33786_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00624_Study_82068_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00624_Study_82068_Series_03.nii.gz
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00909_Study_43253_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00909_Study_43253_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00095_Study_70760_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00095_Study_70760_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00024_Study_30077_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00024_Study_30077_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00344_Study_30044_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00344_Study_30044_Series_03.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00062_Study_48768_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00062_Study_48768_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00606_Study_40311_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00606_Study_40311_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00641_Study_06253_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00641_Study_06253_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00898_Study_83167_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00898_Study_83167_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00062_Study_48768_Series_03.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00062_Study_48768_Series_03.nii.seg.nrrd.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00525_Study_52610_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00525_Study_52610_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00377_Study_63413_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00377_Study_63413_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00481_Study_47041_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00481_Study_47041_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00433_Study_51841_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00433_Study_51841_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00903_Study_73352_Series_03.nii.gz.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00903_Study_73352_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00394_Study_24613_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00394_Study_24613_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00762_Study_21376_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00762_Study_21376_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/Patient_00100_Study_20766_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/male_cases_refined_by_md/masks/Patient_00100_Study_20766_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00661_Study_75023_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00661_Study_75023_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00253_Study_76138_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00253_Study_76138_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00207_Study_24221_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00207_Study_24221_Series_03.nii.gzConverted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00904_Study_62052_Series_03_4.4.7.0.5.5.30705.2.1.1.55414447125483802604653528060000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00904_Study_62052_Series_03_4.4.7.0.5.5.30705.2.1.1.55414447125483802604653528060000.nii.gz
#
#
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00754_Study_04545_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00754_Study_04545_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00168_Study_85765_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00168_Study_85765_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00142_Study_71645_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00142_Study_71645_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00374_Study_42538_Series_05_3.7.8.4.1.8.36286.2.1.1.31878387455567128623067335720000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00374_Study_42538_Series_05_3.7.8.4.1.8.36286.2.1.1.31878387455567128623067335720000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00390_Study_24261_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00390_Study_24261_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00575_Study_26702_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00575_Study_26702_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00580_Study_57252_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00580_Study_57252_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00799_Study_35633_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00799_Study_35633_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_02059_Study_27210_Series_03_5.7.0.4.5.5.40767.2.1.1.66650442278738874425545328480000.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_02059_Study_27210_Series_03_5.7.0.4.5.5.40767.2.1.1.66650442278738874425545328480000.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00859_Study_30038_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00859_Study_30038_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00773_Study_22353_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00773_Study_22353_Series_03.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00382_Study_72664_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00382_Study_72664_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00032_Study_03357_Series_03_5.6.5.0.4.8.88282.2.1.1.37670438875026001270862060530000.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00032_Study_03357_Series_03_5.6.5.0.4.8.88282.2.1.1.37670438875026001270862060530000.nii.seg.nrrd.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00917_Study_03813_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00917_Study_03813_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00926_Study_01533_Series_04.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00926_Study_01533_Series_04.nii.gz
# Converted /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/Patient_00533_Study_82145_Series_03.nii.gz.nii.seg.nrrd to /data/usr/yb107/colon_data/refined_by_mobina/colon_refined_by_mobina/masks/Patient_00533_Study_82145_Series_03.nii.gz

# %% [markdown]
# ## Add Body Mask Paths

# %%
import json, os, glob

# jsonl_path = "/home/yb107/cvpr2025/DukeDiffSeg/data/mobina_mixed_colon_dataset/mobina_mixed_colon_dataset.jsonl"
# body_filled_mask_basedir = (
#     "/data/usr/yb107/colon_data/refined_by_mobina/Body_filled_all"
# )

jsonl_path = "/home/yb107/cvpr2025/DukeDiffSeg/data/c_grade_colons/3d_vlsmv2_c_grade_colon_dataset.jsonl"
body_filled_mask_basedir = "/data/usr/yb107/c_grade_colons/body_filled_masks"

all_Body_filled_mask_paths = glob.glob(
    os.path.join(body_filled_mask_basedir, "*.nii.gz")
)
all_data = []
with open(jsonl_path, "r") as f:
    for line in f:
        data = json.loads(line)
        patient_name = os.path.basename(data["mask"]).split("/")[-1].split(".")[0]
        matching_body_filled_masks = [
            p
            for p in all_Body_filled_mask_paths
            if os.path.basename(p).startswith(patient_name)
        ]
        if len(matching_body_filled_masks) == 0:
            # Try removing the last _part after underscore
            if "_" in patient_name:
                modified_patient_name = "_".join(patient_name.split("_")[:-1])
                matching_body_filled_masks = [
                    p
                    for p in all_Body_filled_mask_paths
                    if os.path.basename(p).startswith(modified_patient_name)
                ]
            if len(matching_body_filled_masks) == 0:
                print(f"No matching body filled mask found for patient: {patient_name}")
            elif len(matching_body_filled_masks) > 1:
                print(
                    f"Multiple matching body filled masks found for patient: {patient_name}"
                )
            else:
                body_filled_mask_path = matching_body_filled_masks[0]
                data["body_filled_mask"] = body_filled_mask_path
                # print(f"Added body filled mask for patient: {patient_name}"

        elif len(matching_body_filled_masks) > 1:
            print(
                f"Multiple matching body filled masks found for patient: {patient_name}"
            )
        else:
            body_filled_mask_path = matching_body_filled_masks[0]
            data["body_filled_mask"] = body_filled_mask_path
            # print(f"Added body filled mask for patient: {patient_name}")
        all_data.append(data)
        # print(patient_name)

# %%
# Write all_data to a new jsonl file
output_jsonl_path = "/home/yb107/cvpr2025/DukeDiffSeg/data/c_grade_colons/3d_vlsmv2_c_grade_colon_dataset_with_body_filled.jsonl"
with open(output_jsonl_path, "w") as f:
    for entry in all_data:
        f.write(json.dumps(entry) + "\n")
